# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv(r"C:\Users\hegde\Desktop\DS Ass Qst\SalaryData_Train.csv")

# %%
df_test = pd.read_csv(r"C:\Users\hegde\Desktop\DS Ass Qst\SalaryData_Test.csv")

# %%
df_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
df_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
data = df_train.append(df_test)
data.reset_index(inplace=True,drop=True)
data
# Out:
# C:\Users\hegde\AppData\Local\Temp\ipykernel_6840\3911916688.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = df_train.append(df_test)
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 45216   33            Private   Bachelors           13        Never-married
# 45217   39            Private   Bachelors           13             Divorced
# 45218   38            Private   Bachelors           13   Married-civ-spouse
# 45219   44            Private   Bachelors           13             Divorced
# 45220   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0            Adm-clerical   Not-in-family                White     Male
# 1         Exec-managerial         Husband                White     Male
# 2       Handlers-cleaners   Not-in-family                White     Male
# 3       Handlers-cleaners         Husband                Black     Male
# 4          Prof-specialty            Wife                Black   Female
# ...                   ...             ...                  ...      ...
# 45216      Prof-specialty       Own-child                White     Male
# 45217      Prof-specialty   Not-in-family                White   Female
# 45218      Prof-specialty         Husband                White     Male
# 45219        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 45220     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0             2174            0            40   United-States   <=50K
# 1                0            0            13   United-States   <=50K
# 2                0            0            40   United-States   <=50K
# 3                0            0            40   United-States   <=50K
# 4                0            0            40            Cuba   <=50K
# ...            ...          ...           ...             ...     ...
# 45216            0            0            40   United-States   <=50K
# 45217            0            0            36   United-States   <=50K
# 45218            0            0            50   United-States   <=50K
# 45219         5455            0            40   United-States   <=50K
# 45220            0            0            60   United-States    >50K
#
# [45221 rows x 14 columns]

# %%
data.shape
# Out:
# (45221, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45221 entries, 0 to 45220
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            45221 non-null  int64
#  1   workclass      45221 non-null  object
#  2   education      45221 non-null  object
#  3   educationno    45221 non-null  int64
#  4   maritalstatus  45221 non-null  object
#  5   occupation     45221 non-null  object
#  6   relationship   45221 non-null  object
#  7   race           45221 non-null  object
#  8   sex            45221 non-null  object
#  9   capitalgain    45221 non-null  int64
#  10  capitalloss    45221 non-null  int64
#  11  hoursperweek   45221 non-null  int64
#  12  native         45221 non-null  object
#  13  Salary         45221 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 4.8+ MB

# %%
data.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  45221.000000  45221.000000  45221.000000  45221.000000  45221.000000
# mean      38.548086     10.118463   1101.454700     88.548617     40.938038
# std       13.217981      2.552909   7506.511295    404.838249     12.007640
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45216    False
# 45217    False
# 45218     True
# 45219    False
# 45220    False
# Length: 45221, dtype: bool

# %%
data[data.duplicated()].shape
# Out:
# (5982, 14)

# %%
data.drop_duplicates(inplace = True)

# %%
data[data.duplicated()].shape
# Out:
# (0, 14)

# %%
data.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
numerical_features=[feature for feature in data.columns if data[feature].dtypes != 'O']

print('Number of numerical variables:', len(numerical_features))

# Visualize the numerical variables
data[numerical_features].head()
# Out:
# Number of numerical variables: 5
#    age  educationno  capitalgain  capitalloss  hoursperweek
# 0   39           13         2174            0            40
# 1   50           13            0            0            13
# 2   38            9            0            0            40
# 3   53            7            0            0            40
# 4   28           13            0            0            40

# %%
discrete_feature=[feature for feature in numerical_features if len(data[feature].unique())<25]
print('Discrete Variables Count: {}'.format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 1

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature]
print('Continuous Feature Count {}'.format(len(continuous_feature)))
# Out:
# Continuous Feature Count 4

# %%
categorical = [var for var in data.columns if data[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))

print('The categorical variables are :\n\n', categorical)
# Out:
# There are 9 categorical variables
#
# The categorical variables are :
#
#  ['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native', 'Salary']

# %%
for var in categorical: 
    
    print(data[var].value_counts())
# Out:
#  Private             27716
#  Self-emp-not-inc     3669
#  Local-gov            2975
#  State-gov            1892
#  Self-emp-inc         1595
#  Federal-gov          1371
#  Without-pay            21
# Name: workclass, dtype: int64
#  HS-grad         12003
#  Some-college     8456
#  Bachelors        6522
#  Masters          2357
#  Assoc-voc        1859
#  Assoc-acdm       1470
#  11th             1422
#  10th             1136
#  7th-8th           801
#  Prof-school       764
#  9th               658
#  12th              540
#  Doctorate         526
#  5th-6th           438
#  1st-4th           217
#  Preschool          70
# Name: education, dtype: int64
#  Married-civ-spouse       17947
#  Never-married            12168
#  Divorced                  5885
#  Separated                 1394
#  Widowed                   1261
#  Married-spouse-absent      552
#  Married-AF-spouse           32
# Name: maritalstatus, dtype: int64
#  Prof-specialty       5516
#  Exec-managerial      5311
#  Adm-clerical         4742
#  Sales                4671
#  Craft-repair         4634
#  Other-service        4252
#  Machine-op-inspct    2439
#  Transport-moving     2032
#  Handlers-cleaners    1712
#  Farming-fishing      1424
#  Tech-support         1325
#  Protective-serv       937
#  Priv-house-serv       230
#  Armed-Forces           14
# Name: occupation, dtype: int64
#  Husband           15645
#  Not-in-family     10530
#  Own-child          5194
#  Unmarried          4547
#  Wife               2004
#  Other-relative     1319
# Name: relationship, dtype: int64
#  White                 33063
#  Black                  4089
#  Asian-Pac-Islander     1299
#  Amer-Indian-Eskimo      435
#  Other                   353
# Name: race, dtype: int64
#  Male      26097
#  Female    13142
# Name: sex, dtype: int64
#  United-States                 35340
#  Mexico                          879
#  Philippines                     281
#  Germany                         193
#  Puerto-Rico                     175
#  Canada                          163
#  El-Salvador                     147
#  India                           147
#  Cuba                            133
#  England                         119
#  China                           113
#  Jamaica                         102
#  South                           101
#  Italy                           100
#  Dominican-Republic               97
#  Japan                            89
#  Guatemala                        84
#  Vietnam                          83
#  Columbia                         82
#  Poland                           81
#  Haiti                            69
#  Portugal                         62
#  Iran                             56
#  Taiwan                           55
#  Greece                           49
#  Nicaragua                        48
#  Peru                             45
#  Ecuador                          43
#  France                           36
#  Ireland                          35
#  Thailand                         29
#  Hong                             28
#  Cambodia                         26
#  Trinadad&Tobago                  26
#  Yugoslavia                       23
#  Outlying-US(Guam-USVI-etc)       22
#  Laos                             21
#  Scotland                         20
#  Honduras                         19
#  Hungary                          18
# Name: native, dtype: int64
#  <=50K    29264
#  >50K      9975
# Name: Salary, dtype: int64

# %% [markdown]
# # Data visualization

# %%
data.corr()
# Out:
# C:\Users\hegde\AppData\Local\Temp\ipykernel_6840\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.030211     0.075495     0.049876      0.066927
# educationno   0.030211     1.000000     0.129552     0.082594      0.136030
# capitalgain   0.075495     0.129552     1.000000    -0.036791      0.082977
# capitalloss   0.049876     0.082594    -0.036791     1.000000      0.050638
# hoursperweek  0.066927     0.136030     0.082977     0.050638      1.000000

# %%
fig= plt.figure(figsize=(18, 6))
sns.heatmap(data.corr(), annot=True);
plt.xticks(rotation=45)
# Out:
# C:\Users\hegde\AppData\Local\Temp\ipykernel_6840\3179787637.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True);
# (array([0.5, 1.5, 2.5, 3.5, 4.5]),
#  [Text(0.5, 0, 'age'),
#   Text(1.5, 0, 'educationno'),
#   Text(2.5, 0, 'capitalgain'),
#   Text(3.5, 0, 'capitalloss'),
#   Text(4.5, 0, 'hoursperweek')])

# %%
for feat in continuous_feature:
    skew = data[feat].skew()
    sns.distplot(data[feat], kde= False, label='Skew = %.3f' %(skew), bins=30)
    plt.legend(loc='best')
    plt.show()
# Out:
# C:\Users\hegde\AppData\Local\Temp\ipykernel_6840\4144242022.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feat], kde= False, label='Skew = %.3f' %(skew), bins=30)

# %% [markdown]
# # Outliers detection

# %%
outliers=data.copy() 
fig, axes=plt.subplots(4,1,figsize=(14,8),sharex=False,sharey=False)
sns.boxplot(x='age',data=outliers,palette='crest',ax=axes[0])
sns.boxplot(x='capitalgain',data=outliers,palette='crest',ax=axes[1])
sns.boxplot(x='capitalloss',data=outliers,palette='crest',ax=axes[2])
sns.boxplot(x='hoursperweek',data=outliers,palette='crest',ax=axes[3])
plt.tight_layout(pad=2.0)

# %%
for feature in continuous_feature:
    df=data.copy()
    df[feature]=np.log(df[feature])
    df.boxplot(column=feature)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\hegde\AppData\Roaming\Python\Python311\site-packages\numpy\lib\function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1257: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1264: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1272: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1273: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\hegde\AppData\Roaming\Python\Python311\site-packages\numpy\lib\function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1257: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1264: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1272: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1273: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],

# %%
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
df= data.copy()
label_encoder = preprocessing.LabelEncoder()
df["education"]=label_encoder.fit_transform(df["education"])
df["workclass"]=label_encoder.fit_transform(df["workclass"])
df["maritalstatus"]=label_encoder.fit_transform(df["maritalstatus"])
df["sex"]=label_encoder.fit_transform(df["sex"])
df["race"]=label_encoder.fit_transform(df["race"])
df["occupation"]=label_encoder.fit_transform(df["occupation"])
df["relationship"]=label_encoder.fit_transform(df["relationship"])
df["native"]=label_encoder.fit_transform(df["native"])
df.head(10)
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
# 5   37          2         12           14              2           3
# 6   49          2          6            5              3           7
# 7   52          4         11            9              2           3
# 8   31          2         12           14              4           9
# 9   42          2          9           13              2           3
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
# 5             5     4    0            0            0            40      37
# 6             1     2    0            0            0            16      21
# 7             0     4    1            0            0            45      37
# 8             1     4    0        14084            0            50      37
# 9             0     4    1         5178            0            40      37
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K
# 5   <=50K
# 6   <=50K
# 7    >50K
# 8    >50K
# 9    >50K

# %%
df['Salary'] = data.Salary
df['Salary'] = np.where(df['Salary'].str.contains(" >50K"), 1, 0)
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features = df[continuous_feature]
df[continuous_feature] = scaler.fit_transform(features.values)
df.head()
# Out:
#         age  workclass  education  educationno  maritalstatus  occupation  \
# 0 -0.023268          5          9           13              4           0
# 1  0.803925          4          9           13              2           3
# 2 -0.098467          2         11            9              0           5
# 3  1.029523          2          1            7              2           5
# 4 -0.850460          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1     0.115168    -0.234655     -0.096815      37
# 1             0     4    1    -0.156786    -0.234655     -2.264094      37
# 2             1     4    1    -0.156786    -0.234655     -0.096815      37
# 3             0     2    1    -0.156786    -0.234655     -0.096815      37
# 4             5     2    0    -0.156786    -0.234655     -0.096815       4
#
#    Salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # SVM model building

# %%
X = df.drop('Salary',axis=1)
y = df['Salary']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
print("Shape of X_train: ",X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of X_train:  (27467, 13)
# Shape of X_test:  (11772, 13)
# Shape of y_train:  (27467,)
# Shape of y_test (11772,)

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
clf = SVC()
param_grid = [{'kernel':['linear', 'rbf'], 'gamma':[0.5,0.1,0.01], 'C':[10,0.1,0.001,0.0001]}]
gsv = RandomizedSearchCV(clf, param_grid,cv = 10, verbose=300)
gsv.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV 1/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 1/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.810 total time= 2.0min
# [CV 2/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 2/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.798 total time= 1.9min
# [CV 3/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 3/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.808 total time= 2.1min
# [CV 4/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 4/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.809 total time= 1.8min
# [CV 5/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 5/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.811 total time= 1.7min
# [CV 6/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 6/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.799 total time= 1.7min
# [CV 7/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 7/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.801 total time= 1.7min
# [CV 8/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 8/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.805 total time= 2.0min
# [CV 9/10; 1/10] START C=10, gamma=0.5, kernel=rbf...............................
# [CV 9/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.816 total time= 1.9min
# [CV 10/10; 1/10] START C=10, gamma=0.5, kernel=rbf..............................
# [CV 10/10; 1/10] END C=10, gamma=0.5, kernel=rbf;, score=0.811 total time= 2.1min
# [CV 1/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 1/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.813 total time=  23.1s
# [CV 2/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 2/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.810 total time=  26.5s
# [CV 3/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 3/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.807 total time=  24.6s
# [CV 4/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 4/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.815 total time=  22.8s
# [CV 5/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 5/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.806 total time=  22.4s
# [CV 6/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 6/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.810 total time=  23.4s
# [CV 7/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 7/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.810 total time=  21.4s
# [CV 8/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 8/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.812 total time=  21.3s
# [CV 9/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf..............................
# [CV 9/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.818 total time=  21.2s
# [CV 10/10; 2/10] START C=0.1, gamma=0.1, kernel=rbf.............................
# [CV 10/10; 2/10] END C=0.1, gamma=0.1, kernel=rbf;, score=0.811 total time=  21.1s
# [CV 1/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 1/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.799 total time= 2.4min
# [CV 2/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 2/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.814 total time= 2.4min
# [CV 3/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 3/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.807 total time= 2.4min
# [CV 4/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 4/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.813 total time= 2.4min
# [CV 5/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 5/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.794 total time= 2.4min
# [CV 6/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 6/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.798 total time= 2.3min
# [CV 7/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 7/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.806 total time= 2.4min
# [CV 8/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 8/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.806 total time= 2.4min
# [CV 9/10; 3/10] START C=10, gamma=0.5, kernel=linear............................
# [CV 9/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.801 total time= 3.0min
# [CV 10/10; 3/10] START C=10, gamma=0.5, kernel=linear...........................
# [CV 10/10; 3/10] END C=10, gamma=0.5, kernel=linear;, score=0.809 total time= 2.7min
# [CV 1/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 1/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.799 total time=  15.9s
# [CV 2/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 2/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.814 total time=  15.1s
# [CV 3/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 3/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.807 total time=  15.2s
# [CV 4/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 4/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.813 total time=  15.7s
# [CV 5/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 5/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.794 total time=  15.5s
# [CV 6/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 6/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.797 total time=  15.2s
# [CV 7/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 7/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.805 total time=  15.1s
# [CV 8/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 8/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.805 total time=  16.0s
# [CV 9/10; 4/10] START C=0.1, gamma=0.1, kernel=linear...........................
# [CV 9/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.801 total time=  17.0s
# [CV 10/10; 4/10] START C=0.1, gamma=0.1, kernel=linear..........................
# [CV 10/10; 4/10] END C=0.1, gamma=0.1, kernel=linear;, score=0.808 total time=  17.8s
# [CV 1/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 1/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.807 total time=  44.2s
# [CV 2/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 2/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.811 total time=  39.0s
# [CV 3/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 3/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.809 total time=  24.0s
# [CV 4/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 4/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.808 total time=  19.8s
# [CV 5/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 5/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.798 total time=  19.5s
# [CV 6/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 6/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.804 total time=  19.2s
# [CV 7/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 7/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.806 total time=  19.6s
# [CV 8/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 8/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.810 total time=  19.3s
# [CV 9/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf.............................
# [CV 9/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.813 total time=  19.2s
# [CV 10/10; 5/10] START C=0.1, gamma=0.01, kernel=rbf............................
# [CV 10/10; 5/10] END C=0.1, gamma=0.01, kernel=rbf;, score=0.812 total time=  19.8s
# [CV 1/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 1/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.751 total time=  13.0s
# [CV 2/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 2/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.751 total time=  13.0s
# [CV 3/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 3/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.751 total time=  12.9s
# [CV 4/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 4/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.750 total time=  12.9s
# [CV 5/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 5/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.750 total time=  12.7s
# [CV 6/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 6/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.753 total time=  13.0s
# [CV 7/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 7/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.754 total time=  13.0s
# [CV 8/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 8/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.750 total time=  13.1s
# [CV 9/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear.......................
# [CV 9/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.752 total time=  12.7s
# [CV 10/10; 6/10] START C=0.0001, gamma=0.01, kernel=linear......................
# [CV 10/10; 6/10] END C=0.0001, gamma=0.01, kernel=linear;, score=0.752 total time=  12.9s
# [CV 1/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 1/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.797 total time=  12.7s
# [CV 2/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 2/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.803 total time=  12.3s
# [CV 3/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 3/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.797 total time=  12.4s
# [CV 4/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 4/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.797 total time=  12.4s
# [CV 5/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 5/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.790 total time=  12.2s
# [CV 6/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 6/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.797 total time=  12.4s
# [CV 7/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 7/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.798 total time=  12.7s
# [CV 8/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 8/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.801 total time=  12.4s
# [CV 9/10; 7/10] START C=0.001, gamma=0.01, kernel=linear........................
# [CV 9/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.790 total time=  12.3s
# [CV 10/10; 7/10] START C=0.001, gamma=0.01, kernel=linear.......................
# [CV 10/10; 7/10] END C=0.001, gamma=0.01, kernel=linear;, score=0.802 total time=  12.2s
# [CV 1/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 1/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.751 total time=  12.8s
# [CV 2/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 2/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.751 total time=  13.4s
# [CV 3/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 3/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.751 total time=  13.3s
# [CV 4/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 4/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.750 total time=  13.0s
# [CV 5/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 5/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.750 total time=  13.3s
# [CV 6/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 6/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.753 total time=  13.2s
# [CV 7/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 7/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.754 total time=  12.9s
# [CV 8/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 8/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.750 total time=  12.9s
# [CV 9/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear........................
# [CV 9/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.752 total time=  12.6s
# [CV 10/10; 8/10] START C=0.0001, gamma=0.1, kernel=linear.......................
# [CV 10/10; 8/10] END C=0.0001, gamma=0.1, kernel=linear;, score=0.752 total time=  13.9s
# [CV 1/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 1/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.799 total time= 2.4min
# [CV 2/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 2/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.814 total time= 2.4min
# [CV 3/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 3/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.807 total time= 2.4min
# [CV 4/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 4/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.813 total time= 2.4min
# [CV 5/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 5/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.794 total time= 2.4min
# [CV 6/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 6/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.798 total time= 2.4min
# [CV 7/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 7/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.806 total time= 2.5min
# [CV 8/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 8/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.806 total time= 2.4min
# [CV 9/10; 9/10] START C=10, gamma=0.01, kernel=linear...........................
# [CV 9/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.801 total time= 2.4min
# [CV 10/10; 9/10] START C=10, gamma=0.01, kernel=linear..........................
# [CV 10/10; 9/10] END C=10, gamma=0.01, kernel=linear;, score=0.809 total time= 2.5min
# [CV 1/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 1/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.797 total time=  15.0s
# [CV 2/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 2/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.803 total time=  14.6s
# [CV 3/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 3/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.797 total time=  13.5s
# [CV 4/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 4/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.797 total time=  12.6s
# [CV 5/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 5/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.790 total time=  12.2s
# [CV 6/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 6/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.797 total time=  12.5s
# [CV 7/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 7/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.798 total time=  12.3s
# [CV 8/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 8/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.801 total time=  12.3s
# [CV 9/10; 10/10] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 9/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.790 total time=  12.5s
# [CV 10/10; 10/10] START C=0.001, gamma=0.1, kernel=linear.......................
# [CV 10/10; 10/10] END C=0.001, gamma=0.1, kernel=linear;, score=0.802 total time=  12.3s
# RandomizedSearchCV(cv=10, estimator=SVC(),
#                    param_distributions=[{'C': [10, 0.1, 0.001, 0.0001],
#                                          'gamma': [0.5, 0.1, 0.01],
#                                          'kernel': ['linear', 'rbf']}],
#                    verbose=300)

# %%
y_pred = gsv.predict(X_test)

# %%
gsv.best_score_
# Out:
# 0.8113010922860694

# %%
gsv.best_params_
# Out:
# {'kernel': 'rbf', 'gamma': 0.1, 'C': 0.1}

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, linewidth=2, color='red')
plt.plot([0,1], [0,1], 'k--' )
plt.rcParams['font.size'] = 12
plt.title('ROC curve for SVM Classifier using Polynomial Kernel for Predicting Size_category')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.show()

ROC_AUC = roc_auc_score(y_test, y_pred)
print('ROC AUC : {:.4f}'.format(ROC_AUC))
# Out:
# ROC AUC : 0.6775

# %% [markdown]
# # Using linear kernel

# %%
clf1 = SVC(kernel = 'linear', C = 10, gamma = 0.5)
clf1.fit(X_train, y_train)
y_pred_ = clf1.predict(X_test)
acc = accuracy_score(y_pred_, y_test)
acc
# Out:
# 0.8038566089024805

# %%
con_mat = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_pred_)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, linewidth=2, color='red')
plt.plot([0,1], [0,1], 'k--' )
plt.rcParams['font.size'] = 12
plt.title('ROC curve for SVM Classifier using Polynomial Kernel for Predicting Size_category')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.show()

ROC_AUC = roc_auc_score(y_test, y_pred_)
print('ROC AUC : {:.4f}'.format(ROC_AUC))
# Out:
# ROC AUC : 0.6444

# %% [markdown]
# # Using ploy kernel

# %%
clf2 = SVC(kernel='poly')
clf2.fit(X_train,y_train)
y_pred_2 = clf2.predict(X_test)
acc = accuracy_score(y_test,y_pred_2)*100
print('Accuracy=',acc)
confusion_matrix(y_test,y_pred_2)
# Out:
# Accuracy= 81.36255521576624
# array([[8573,  209],
#        [1985, 1005]], dtype=int64)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_pred_2)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, linewidth=2, color='red')
plt.plot([0,1], [0,1], 'k--' )
plt.rcParams['font.size'] = 12
plt.title('ROC curve for SVM Classifier using Polynomial Kernel for Predicting Size_category')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.show()

ROC_AUC = roc_auc_score(y_test, y_pred_2)
print('ROC AUC : {:.4f}'.format(ROC_AUC))
# Out:
# ROC AUC : 0.6562
